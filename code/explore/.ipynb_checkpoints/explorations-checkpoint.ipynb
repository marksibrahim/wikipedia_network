# %%
import pandas as pd
import json

# %%
#load results data (~ 2 min runtime)

results_path = "/Users/mark/Desktop/wiki_v3/results/"
df = pd.read_json(results_path + "full_tdict.json", orient="index")
df.columns = ['clicks', 'path_size', 'end_page']

# %%
#what's the center?
    #page with most clicks? (most linked page)
#print top 50
df.sort(columns='clicks', ascending=False).head(100)

#worth exploring these "exceeded 10,000 click limit"
# Out:
#                                     clicks  path_size  \
# Census-Designated Place         2446384566     100000
# Presentation                    1529375020     100000
# Lecture                         1529227074     100000
# Secondary education              377085542     100000
# Cancer                           166094374     100000
# Fossil Fuel                      156125912     100000
# Existence                        146917502         70
# Reality                          146916452         80
# Newcastle Upon Tyne               93269194     100000
# Sailing ship                      85399268     100000
# Schooner                          85396830     100000
# Marriage                          84388452     100000
# Spouse                            84380472     100000
# Consciousness                     73586602         70
# Conscious                         73521396         80
# Modern philosophy                 72217152        100
# ...

# %%
#print bottom 50
df.sort(columns='clicks').head(5)

#graph distribution
# Out:
#                          clicks  path_size   end_page
# ＃GamerGate                    0         62  Awareness
# St James' Day Battle          0        290  Awareness
# Jim McKenny                   0        320  Awareness
# Jim McLaughlin (jockey)       0         70  dead link
# Jim McLean                    0        310  Awareness
